# %%
import pandas as pd

# %%
cement = pd.read_excel("Cement.xlsx")
cement
# Out:
#                       Company Name                            Corrdinates  \
# 0                  A-1 Transit Mix         POINT (-73.8282019 40.8844176)
# 1       Advanced Transit Mix Corp.          POINT (-73.9236332 40.708784)
# 2         All American Transit Mix         POINT (-73.9312489 40.7066136)
# 3               All Boro Ready Mix                    40.76761, -73.84021
# 4   All County Mobile Concrete Inc  POINT (-73.8731463 40.95471659999999)
# ..                             ...                                    ...
# 95          United Transit Mix Inc         POINT (-73.9348009 40.7067429)
# 96        Weldon Concrete - Linden         POINT (-74.2360551 40.6038712)
# 97         Mark Gallagher Concrete                     40.5452, -74.27771
# 98            Brothers II Concrete                    40.55034, -74.23124
# 99            All Seasons ReadyMix                    40.53368, -74.23379
#
#                                               Address  \
# ...
